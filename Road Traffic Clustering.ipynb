# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans,DBSCAN
import warnings
warnings.filterwarnings("ignore")
import plotly.express as px

# %%
df=pd.read_csv("dft-road-casualty-statistics-accident-last-5-years.csv")

# %%
df
# Out:
#        accident_index  accident_year accident_reference  \
# 0       2016010000005           2016          010000005
# 1       2016010000006           2016          010000006
# 2       2016010000008           2016          010000008
# 3       2016010000016           2016          010000016
# 4       2016010000018           2016          010000018
# ...               ...            ...                ...
# 597968  2020991027064           2020          991027064
# 597969  2020991029573           2020          991029573
# 597970  2020991030297           2020          991030297
# 597971  2020991030900           2020          991030900
# 597972  2020991032575           2020          991032575
#
#         location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 0                    519310.0                188730.0  -0.279323  51.584754
# 1                    551920.0                174560.0   0.184928  51.449595
# 2                    505930.0                183850.0  -0.473837  51.543563
# 3                    527770.0                168930.0  -0.164442  51.404958
# 4                    510740.0                177230.0  -0.406580  51.483139
# ...                       ...                     ...        ...        ...
# 597968               343034.0                731654.0  -2.926320  56.473539
# 597969               257963.0                658891.0  -4.267565  55.802353
# 597970               383664.0                810646.0  -2.271903  57.186317
# 597971               277161.0                674852.0  -3.968753  55.950940
# 597972               240402.0                681950.0  -4.561040  56.003843
#
#         police_force  accident_severity  number_of_vehicles  ...  \
# 0                  1                  3                   2  ...
# 1                  1                  3                   1  ...
# 2                  1                  3                   1  ...
# 3                  1                  3                   1  ...
# 4                  1                  3                   2  ...
# ...              ...                ...                 ...  ...
# 597968            99                  2                   2  ...
# 597969            99                  3                   1  ...
# 597970            99                  2                   2  ...
# 597971            99                  3                   2  ...
# 597972            99                  3                   1  ...
#
#         pedestrian_crossing_physical_facilities light_conditions  \
# 0                                             0                5
# 1                                             0                4
# 2                                             0                4
# 3                                             0                1
# 4                                             0                1
# ...                                         ...              ...
# 597968                                        0                1
# 597969                                        0                1
# 597970                                        0                1
# 597971                                        0                1
# 597972                                        0                1
#
#         weather_conditions road_surface_conditions  \
# 0                        1                       1
# 1                        1                       1
# 2                        1                       1
# 3                        1                       1
# 4                        1                       1
# ...                    ...                     ...
# 597968                   1                       1
# 597969                   1                       1
# 597970                   1                       1
# 597971                   1                       1
# 597972                   1                       1
#
#         special_conditions_at_site carriageway_hazards urban_or_rural_area  \
# 0                                0                   0                   1
# 1                                0                   0                   1
# 2                                0                   0                   1
# 3                                0                   0                   1
# 4                                0                   0                   1
# ...                            ...                 ...                 ...
# 597968                           0                   0                   1
# 597969                           0                   0                   1
# 597970                           0                   0                   2
# 597971                           0                   0                   1
# 597972                           0                   2                   1
#
#         did_police_officer_attend_scene_of_accident  trunk_road_flag  \
# 0                                                 1                2
# 1                                                 1                2
# 2                                                 1                2
# 3                                                 1                2
# 4                                                 1                2
# ...                                             ...              ...
# 597968                                            1               -1
# 597969                                            2               -1
# 597970                                            1               -1
# 597971                                            2               -1
# 597972                                            1               -1
#
#         lsoa_of_accident_location
# 0                       E01000543
# 1                       E01000375
# 2                       E01033725
# 3                       E01003379
# 4                       E01002583
# ...                           ...
# 597968                         -1
# 597969                         -1
# 597970                         -1
# 597971                         -1
# 597972                         -1
#
# [597973 rows x 36 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 597973 entries, 0 to 597972
# Data columns (total 36 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   accident_index                               597973 non-null  object
#  1   accident_year                                597973 non-null  int64
#  2   accident_reference                           597973 non-null  object
#  3   location_easting_osgr                        597850 non-null  float64
#  4   location_northing_osgr                       597850 non-null  float64
#  5   longitude                                    597840 non-null  float64
#  6   latitude                                     597840 non-null  float64
#  7   police_force                                 597973 non-null  int64
#  8   accident_severity                            597973 non-null  int64
#  9   number_of_vehicles                           597973 non-null  int64
#  10  number_of_casualties                         597973 non-null  int64
#  11  date                                         597973 non-null  object
#  12  day_of_week                                  597973 non-null  int64
#  13  time                                         597973 non-null  object
#  14  local_authority_district                     597973 non-null  int64
#  15  local_authority_ons_district                 597973 non-null  object
#  16  local_authority_highway                      597973 non-null  object
#  17  first_road_class                             597973 non-null  int64
#  18  first_road_number                            597973 non-null  int64
#  19  road_type                                    597973 non-null  int64
#  20  speed_limit                                  597936 non-null  float64
#  21  junction_detail                              597973 non-null  int64
#  22  junction_control                             597973 non-null  int64
#  23  second_road_class                            597973 non-null  int64
#  24  second_road_number                           597973 non-null  int64
#  25  pedestrian_crossing_human_control            597973 non-null  int64
#  26  pedestrian_crossing_physical_facilities      597973 non-null  int64
#  27  light_conditions                             597973 non-null  int64
#  28  weather_conditions                           597973 non-null  int64
#  29  road_surface_conditions                      597973 non-null  int64
#  30  special_conditions_at_site                   597973 non-null  int64
#  31  carriageway_hazards                          597973 non-null  int64
#  32  urban_or_rural_area                          597973 non-null  int64
#  33  did_police_officer_attend_scene_of_accident  597973 non-null  int64
#  34  trunk_road_flag                              597973 non-null  int64
#  35  lsoa_of_accident_location                    597973 non-null  object
# dtypes: float64(5), int64(24), object(7)
# memory usage: 164.2+ MB

# %%
df['longitude'].plot(kind='line', figsize=(8, 4), title='longitude')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df['location_northing_osgr'].plot(kind='line', figsize=(8, 4), title='location_northing_osgr')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df['location_easting_osgr'].plot(kind='line', figsize=(8, 4), title='location_easting_osgr')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df['accident_year'].plot(kind='line', figsize=(8, 4), title='accident_year')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['accident_year']
  ys = series['latitude']
  
  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('accident_year', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('accident_year')
_ = plt.ylabel('latitude')

# %%
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['accident_year']
  ys = series['longitude']
  
  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('accident_year', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('accident_year')
_ = plt.ylabel('longitude')

# %%
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['accident_year']
  ys = series['location_northing_osgr']
  
  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('accident_year', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('accident_year')
_ = plt.ylabel('location_northing_osgr')

# %%
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['accident_year']
  ys = series['location_easting_osgr']
  
  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('accident_year', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('accident_year')
_ = plt.ylabel('location_easting_osgr')

# %%
df.plot(kind='scatter', x='longitude', y='latitude', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df.plot(kind='scatter', x='location_northing_osgr', y='longitude', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df.plot(kind='scatter', x='location_easting_osgr', y='location_northing_osgr', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df.plot(kind='scatter', x='accident_year', y='location_easting_osgr', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df['longitude'].plot(kind='hist', bins=20, title='longitude')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df['location_northing_osgr'].plot(kind='hist', bins=20, title='location_northing_osgr')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df['location_easting_osgr'].plot(kind='hist', bins=20, title='location_easting_osgr')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df['accident_year'].plot(kind='hist', bins=20, title='accident_year')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df.isna().sum()
# Out:
# accident_index                                   0
# accident_year                                    0
# accident_reference                               0
# location_easting_osgr                          123
# location_northing_osgr                         123
# longitude                                      133
# latitude                                       133
# police_force                                     0
# accident_severity                                0
# number_of_vehicles                               0
# number_of_casualties                             0
# date                                             0
# day_of_week                                      0
# time                                             0
# local_authority_district                         0
# local_authority_ons_district                     0
# local_authority_highway                          0
# first_road_class                                 0
# first_road_number                                0
# road_type                                        0
# speed_limit                                     37
# junction_detail                                  0
# junction_control                                 0
# second_road_class                                0
# second_road_number                               0
# pedestrian_crossing_human_control                0
# pedestrian_crossing_physical_facilities          0
# light_conditions                                 0
# weather_conditions                               0
# road_surface_conditions                          0
# special_conditions_at_site                       0
# carriageway_hazards                              0
# urban_or_rural_area                              0
# did_police_officer_attend_scene_of_accident      0
# trunk_road_flag                                  0
# lsoa_of_accident_location                        0
# dtype: int64

# %%
df.dropna(inplace=True)
df.isna().sum()
# Out:
# accident_index                                 0
# accident_year                                  0
# accident_reference                             0
# location_easting_osgr                          0
# location_northing_osgr                         0
# longitude                                      0
# latitude                                       0
# police_force                                   0
# accident_severity                              0
# number_of_vehicles                             0
# number_of_casualties                           0
# date                                           0
# day_of_week                                    0
# time                                           0
# local_authority_district                       0
# local_authority_ons_district                   0
# local_authority_highway                        0
# first_road_class                               0
# first_road_number                              0
# road_type                                      0
# speed_limit                                    0
# junction_detail                                0
# junction_control                               0
# second_road_class                              0
# second_road_number                             0
# pedestrian_crossing_human_control              0
# pedestrian_crossing_physical_facilities        0
# light_conditions                               0
# weather_conditions                             0
# road_surface_conditions                        0
# special_conditions_at_site                     0
# carriageway_hazards                            0
# urban_or_rural_area                            0
# did_police_officer_attend_scene_of_accident    0
# trunk_road_flag                                0
# lsoa_of_accident_location                      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
unwanted_cols=['lsoa_of_accident_location','accident_index','accident_reference','date','accident_year']

# %%
df.drop(columns=unwanted_cols,inplace=True)

# %%
df
# Out:
#         location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 0                    519310.0                188730.0  -0.279323  51.584754
# 1                    551920.0                174560.0   0.184928  51.449595
# 2                    505930.0                183850.0  -0.473837  51.543563
# 3                    527770.0                168930.0  -0.164442  51.404958
# 4                    510740.0                177230.0  -0.406580  51.483139
# ...                       ...                     ...        ...        ...
# 597968               343034.0                731654.0  -2.926320  56.473539
# 597969               257963.0                658891.0  -4.267565  55.802353
# 597970               383664.0                810646.0  -2.271903  57.186317
# 597971               277161.0                674852.0  -3.968753  55.950940
# 597972               240402.0                681950.0  -4.561040  56.003843
#
#         police_force  accident_severity  number_of_vehicles  \
# 0                  1                  3                   2
# 1                  1                  3                   1
# 2                  1                  3                   1
# 3                  1                  3                   1
# 4                  1                  3                   2
# ...              ...                ...                 ...
# 597968            99                  2                   2
# 597969            99                  3                   1
# 597970            99                  2                   2
# 597971            99                  3                   2
# 597972            99                  3                   1
#
#         number_of_casualties  day_of_week   time  ...  \
# 0                          1            3  02:30  ...
# 1                          1            3  00:37  ...
# 2                          1            3  01:25  ...
# 3                          1            3  09:15  ...
# 4                          1            3  07:53  ...
# ...                      ...          ...    ...  ...
# 597968                     1            4  14:30  ...
# 597969                     1            6  15:05  ...
# 597970                     1            4  12:42  ...
# 597971                     1            3  14:00  ...
# 597972                     1            3  13:50  ...
#
#         pedestrian_crossing_human_control  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       0
# ...                                   ...
# 597968                                  0
# 597969                                  0
# 597970                                  0
# 597971                                  0
# 597972                                  0
#
#        pedestrian_crossing_physical_facilities light_conditions  \
# 0                                            0                5
# 1                                            0                4
# 2                                            0                4
# 3                                            0                1
# 4                                            0                1
# ...                                        ...              ...
# 597968                                       0                1
# 597969                                       0                1
# 597970                                       0                1
# 597971                                       0                1
# 597972                                       0                1
#
#         weather_conditions  road_surface_conditions  \
# 0                        1                        1
# 1                        1                        1
# 2                        1                        1
# 3                        1                        1
# 4                        1                        1
# ...                    ...                      ...
# 597968                   1                        1
# 597969                   1                        1
# 597970                   1                        1
# 597971                   1                        1
# 597972                   1                        1
#
#         special_conditions_at_site  carriageway_hazards  urban_or_rural_area  \
# 0                                0                    0                    1
# 1                                0                    0                    1
# 2                                0                    0                    1
# 3                                0                    0                    1
# 4                                0                    0                    1
# ...                            ...                  ...                  ...
# 597968                           0                    0                    1
# 597969                           0                    0                    1
# 597970                           0                    0                    2
# 597971                           0                    0                    1
# 597972                           0                    2                    1
#
#         did_police_officer_attend_scene_of_accident  trunk_road_flag
# 0                                                 1                2
# 1                                                 1                2
# 2                                                 1                2
# 3                                                 1                2
# 4                                                 1                2
# ...                                             ...              ...
# 597968                                            1               -1
# 597969                                            2               -1
# 597970                                            1               -1
# 597971                                            2               -1
# 597972                                            1               -1
#
# [597803 rows x 31 columns]

# %%
df['time']
# Out:
# 0         02:30
# 1         00:37
# 2         01:25
# 3         09:15
# 4         07:53
#           ...
# 597968    14:30
# 597969    15:05
# 597970    12:42
# 597971    14:00
# 597972    13:50
# Name: time, Length: 597803, dtype: object

# %%
df['time'] = pd.to_datetime(df['time'])
df['hour'] = df['time'].dt.hour
df
# Out:
#         location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 0                    519310.0                188730.0  -0.279323  51.584754
# 1                    551920.0                174560.0   0.184928  51.449595
# 2                    505930.0                183850.0  -0.473837  51.543563
# 3                    527770.0                168930.0  -0.164442  51.404958
# 4                    510740.0                177230.0  -0.406580  51.483139
# ...                       ...                     ...        ...        ...
# 597968               343034.0                731654.0  -2.926320  56.473539
# 597969               257963.0                658891.0  -4.267565  55.802353
# 597970               383664.0                810646.0  -2.271903  57.186317
# 597971               277161.0                674852.0  -3.968753  55.950940
# 597972               240402.0                681950.0  -4.561040  56.003843
#
#         police_force  accident_severity  number_of_vehicles  \
# 0                  1                  3                   2
# 1                  1                  3                   1
# 2                  1                  3                   1
# 3                  1                  3                   1
# 4                  1                  3                   2
# ...              ...                ...                 ...
# 597968            99                  2                   2
# 597969            99                  3                   1
# 597970            99                  2                   2
# 597971            99                  3                   2
# 597972            99                  3                   1
#
#         number_of_casualties  day_of_week                time  ...  \
# 0                          1            3 2024-07-02 02:30:00  ...
# 1                          1            3 2024-07-02 00:37:00  ...
# 2                          1            3 2024-07-02 01:25:00  ...
# 3                          1            3 2024-07-02 09:15:00  ...
# 4                          1            3 2024-07-02 07:53:00  ...
# ...                      ...          ...                 ...  ...
# 597968                     1            4 2024-07-02 14:30:00  ...
# 597969                     1            6 2024-07-02 15:05:00  ...
# 597970                     1            4 2024-07-02 12:42:00  ...
# 597971                     1            3 2024-07-02 14:00:00  ...
# 597972                     1            3 2024-07-02 13:50:00  ...
#
#         pedestrian_crossing_physical_facilities light_conditions  \
# 0                                             0                5
# 1                                             0                4
# 2                                             0                4
# 3                                             0                1
# 4                                             0                1
# ...                                         ...              ...
# 597968                                        0                1
# 597969                                        0                1
# 597970                                        0                1
# 597971                                        0                1
# 597972                                        0                1
#
#        weather_conditions  road_surface_conditions  \
# 0                       1                        1
# 1                       1                        1
# 2                       1                        1
# 3                       1                        1
# 4                       1                        1
# ...                   ...                      ...
# 597968                  1                        1
# 597969                  1                        1
# 597970                  1                        1
# 597971                  1                        1
# 597972                  1                        1
#
#         special_conditions_at_site  carriageway_hazards  urban_or_rural_area  \
# 0                                0                    0                    1
# 1                                0                    0                    1
# 2                                0                    0                    1
# 3                                0                    0                    1
# 4                                0                    0                    1
# ...                            ...                  ...                  ...
# 597968                           0                    0                    1
# 597969                           0                    0                    1
# 597970                           0                    0                    2
# 597971                           0                    0                    1
# 597972                           0                    2                    1
#
#         did_police_officer_attend_scene_of_accident  trunk_road_flag  hour
# 0                                                 1                2     2
# 1                                                 1                2     0
# 2                                                 1                2     1
# 3                                                 1                2     9
# 4                                                 1                2     7
# ...                                             ...              ...   ...
# 597968                                            1               -1    14
# 597969                                            2               -1    15
# 597970                                            1               -1    12
# 597971                                            2               -1    14
# 597972                                            1               -1    13
#
# [597803 rows x 32 columns]

# %%
df['time']=df['hour']
df.drop('hour',axis=1,inplace=True)
df
# Out:
#         location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 0                    519310.0                188730.0  -0.279323  51.584754
# 1                    551920.0                174560.0   0.184928  51.449595
# 2                    505930.0                183850.0  -0.473837  51.543563
# 3                    527770.0                168930.0  -0.164442  51.404958
# 4                    510740.0                177230.0  -0.406580  51.483139
# ...                       ...                     ...        ...        ...
# 597968               343034.0                731654.0  -2.926320  56.473539
# 597969               257963.0                658891.0  -4.267565  55.802353
# 597970               383664.0                810646.0  -2.271903  57.186317
# 597971               277161.0                674852.0  -3.968753  55.950940
# 597972               240402.0                681950.0  -4.561040  56.003843
#
#         police_force  accident_severity  number_of_vehicles  \
# 0                  1                  3                   2
# 1                  1                  3                   1
# 2                  1                  3                   1
# 3                  1                  3                   1
# 4                  1                  3                   2
# ...              ...                ...                 ...
# 597968            99                  2                   2
# 597969            99                  3                   1
# 597970            99                  2                   2
# 597971            99                  3                   2
# 597972            99                  3                   1
#
#         number_of_casualties  day_of_week  time  ...  \
# 0                          1            3     2  ...
# 1                          1            3     0  ...
# 2                          1            3     1  ...
# 3                          1            3     9  ...
# 4                          1            3     7  ...
# ...                      ...          ...   ...  ...
# 597968                     1            4    14  ...
# 597969                     1            6    15  ...
# 597970                     1            4    12  ...
# 597971                     1            3    14  ...
# 597972                     1            3    13  ...
#
#         pedestrian_crossing_human_control  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       0
# ...                                   ...
# 597968                                  0
# 597969                                  0
# 597970                                  0
# 597971                                  0
# 597972                                  0
#
#        pedestrian_crossing_physical_facilities light_conditions  \
# 0                                            0                5
# 1                                            0                4
# 2                                            0                4
# 3                                            0                1
# 4                                            0                1
# ...                                        ...              ...
# 597968                                       0                1
# 597969                                       0                1
# 597970                                       0                1
# 597971                                       0                1
# 597972                                       0                1
#
#         weather_conditions  road_surface_conditions  \
# 0                        1                        1
# 1                        1                        1
# 2                        1                        1
# 3                        1                        1
# 4                        1                        1
# ...                    ...                      ...
# 597968                   1                        1
# 597969                   1                        1
# 597970                   1                        1
# 597971                   1                        1
# 597972                   1                        1
#
#         special_conditions_at_site  carriageway_hazards  urban_or_rural_area  \
# 0                                0                    0                    1
# 1                                0                    0                    1
# 2                                0                    0                    1
# 3                                0                    0                    1
# 4                                0                    0                    1
# ...                            ...                  ...                  ...
# 597968                           0                    0                    1
# 597969                           0                    0                    1
# 597970                           0                    0                    2
# 597971                           0                    0                    1
# 597972                           0                    2                    1
#
#         did_police_officer_attend_scene_of_accident  trunk_road_flag
# 0                                                 1                2
# 1                                                 1                2
# 2                                                 1                2
# 3                                                 1                2
# 4                                                 1                2
# ...                                             ...              ...
# 597968                                            1               -1
# 597969                                            2               -1
# 597970                                            1               -1
# 597971                                            2               -1
# 597972                                            1               -1
#
# [597803 rows x 31 columns]

# %%
obj_cols=[]
for i in df.columns:
    if df[i].dtype=='object':
        obj_cols.append(i)
obj_cols
# Out:
# ['local_authority_ons_district', 'local_authority_highway']

# %%
df['local_authority_ons_district'].nunique()
# Out:
# 383

# %%
df['local_authority_highway'].nunique()
# Out:
# 208

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
for i in obj_cols:
    df[i]=le.fit_transform(df[i])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 597803 entries, 0 to 597972
# Data columns (total 31 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   location_easting_osgr                        597803 non-null  float64
#  1   location_northing_osgr                       597803 non-null  float64
#  2   longitude                                    597803 non-null  float64
#  3   latitude                                     597803 non-null  float64
#  4   police_force                                 597803 non-null  int64
#  5   accident_severity                            597803 non-null  int64
#  6   number_of_vehicles                           597803 non-null  int64
#  7   number_of_casualties                         597803 non-null  int64
#  8   day_of_week                                  597803 non-null  int64
#  9   time                                         597803 non-null  int32
#  10  local_authority_district                     597803 non-null  int64
#  11  local_authority_ons_district                 597803 non-null  int32
#  12  local_authority_highway                      597803 non-null  int32
#  13  first_road_class                             597803 non-null  int64
#  14  first_road_number                            597803 non-null  int64
#  15  road_type                                    597803 non-null  int64
#  16  speed_limit                                  597803 non-null  float64
#  17  junction_detail                              597803 non-null  int64
#  18  junction_control                             597803 non-null  int64
#  19  second_road_class                            597803 non-null  int64
#  20  second_road_number                           597803 non-null  int64
#  21  pedestrian_crossing_human_control            597803 non-null  int64
#  22  pedestrian_crossing_physical_facilities      597803 non-null  int64
#  23  light_conditions                             597803 non-null  int64
#  24  weather_conditions                           597803 non-null  int64
#  25  road_surface_conditions                      597803 non-null  int64
#  26  special_conditions_at_site                   597803 non-null  int64
#  27  carriageway_hazards                          597803 non-null  int64
#  28  urban_or_rural_area                          597803 non-null  int64
#  29  did_police_officer_attend_scene_of_accident  597803 non-null  int64
#  30  trunk_road_flag                              597803 non-null  int64
# dtypes: float64(5), int32(3), int64(23)
# memory usage: 139.1 MB

# %%
df.describe()
# Out:
#        location_easting_osgr  location_northing_osgr      longitude  \
# count          597803.000000            5.978030e+05  597803.000000
# mean           451702.219790            2.820424e+05      -1.260248
# std             94931.246353            1.528678e+05       1.392037
# min             64084.000000            1.023500e+04      -7.525273
# 25%            388019.500000            1.757050e+05      -2.180568
# 50%            457990.000000            2.227060e+05      -1.143597
# 75%            528979.500000            3.873815e+05      -0.141018
# max            655391.000000            1.209512e+06       1.759641
#
#             latitude   police_force  accident_severity  number_of_vehicles  \
# count  597803.000000  597803.000000      597803.000000       597803.000000
# mean       52.425666      28.571901           2.792090            1.842221
# std         1.376893      24.913474           0.437892            0.709945
# min        49.912362       1.000000           1.000000            1.000000
# 25%        51.467411       5.000000           3.000000            1.000000
# 50%        51.887986      23.000000           3.000000            2.000000
# 75%        53.380797      45.000000           3.000000            2.000000
# max        60.763722      99.000000           3.000000           24.000000
#
#        number_of_casualties    day_of_week           time  ...  \
# count         597803.000000  597803.000000  597803.000000  ...
# mean               1.307260       4.109941      13.614164  ...
# std                0.756517       1.924952       5.146324  ...
# min                1.000000       1.000000       0.000000  ...
# 25%                1.000000       2.000000      10.000000  ...
# 50%                1.000000       4.000000      14.000000  ...
# 75%                1.000000       6.000000      17.000000  ...
# max               59.000000       7.000000      23.000000  ...
#
#        pedestrian_crossing_human_control  \
# count                      597803.000000
# mean                            0.204870
# std                             1.289671
# min                            -1.000000
# 25%                             0.000000
# 50%                             0.000000
# 75%                             0.000000
# max                             9.000000
#
#        pedestrian_crossing_physical_facilities  light_conditions  \
# count                            597803.000000     597803.000000
# mean                                  1.044508          2.024152
# std                                   2.260131          1.713950
# min                                  -1.000000         -1.000000
# 25%                                   0.000000          1.000000
# 50%                                   0.000000          1.000000
# 75%                                   0.000000          4.000000
# max                                   9.000000          7.000000
#
#        weather_conditions  road_surface_conditions  \
# count        597803.00000            597803.000000
# mean              1.62780                 1.364006
# std               1.79121                 0.886070
# min              -1.00000                -1.000000
# 25%               1.00000                 1.000000
# 50%               1.00000                 1.000000
# 75%               1.00000                 2.000000
# max               9.00000                 9.000000
#
#        special_conditions_at_site  carriageway_hazards  urban_or_rural_area  \
# count               597803.000000        597803.000000        597803.000000
# mean                     0.195784             0.151650             1.331313
# std                      1.163503             1.049602             0.470700
# min                     -1.000000            -1.000000            -1.000000
# 25%                      0.000000             0.000000             1.000000
# 50%                      0.000000             0.000000             1.000000
# 75%                      0.000000             0.000000             2.000000
# max                      9.000000             9.000000             3.000000
#
#        did_police_officer_attend_scene_of_accident  trunk_road_flag
# count                                597803.000000    597803.000000
# mean                                      1.316372         1.669793
# std                                       0.537868         0.863529
# min                                      -1.000000        -1.000000
# 25%                                       1.000000         2.000000
# 50%                                       1.000000         2.000000
# 75%                                       2.000000         2.000000
# max                                       3.000000         2.000000
#
# [8 rows x 31 columns]

# %%
# from sklearn.preprocessing import StandardScaler

# %%
# sc=StandardScaler()

# %%
# cols=list(df.columns)
# l=['location_easting_osgr','location_northing_osgr','longitude','latitude']
# for i in l:
#     cols.remove(i)
# cols

# %%
# for i in cols:
#     scaled_df=sc.fit_transform(df[cols])
# scaled_df

# %%
# scaled_df=pd.DataFrame(scaled_df,columns=cols)
# for i in cols:
#     df[i]=scaled_df[i]
# df

# %%
df
# Out:
#         location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 0                    519310.0                188730.0  -0.279323  51.584754
# 1                    551920.0                174560.0   0.184928  51.449595
# 2                    505930.0                183850.0  -0.473837  51.543563
# 3                    527770.0                168930.0  -0.164442  51.404958
# 4                    510740.0                177230.0  -0.406580  51.483139
# ...                       ...                     ...        ...        ...
# 597968               343034.0                731654.0  -2.926320  56.473539
# 597969               257963.0                658891.0  -4.267565  55.802353
# 597970               383664.0                810646.0  -2.271903  57.186317
# 597971               277161.0                674852.0  -3.968753  55.950940
# 597972               240402.0                681950.0  -4.561040  56.003843
#
#         police_force  accident_severity  number_of_vehicles  \
# 0                  1                  3                   2
# 1                  1                  3                   1
# 2                  1                  3                   1
# 3                  1                  3                   1
# 4                  1                  3                   2
# ...              ...                ...                 ...
# 597968            99                  2                   2
# 597969            99                  3                   1
# 597970            99                  2                   2
# 597971            99                  3                   2
# 597972            99                  3                   1
#
#         number_of_casualties  day_of_week  time  ...  \
# 0                          1            3     2  ...
# 1                          1            3     0  ...
# 2                          1            3     1  ...
# 3                          1            3     9  ...
# 4                          1            3     7  ...
# ...                      ...          ...   ...  ...
# 597968                     1            4    14  ...
# 597969                     1            6    15  ...
# 597970                     1            4    12  ...
# 597971                     1            3    14  ...
# 597972                     1            3    13  ...
#
#         pedestrian_crossing_human_control  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       0
# ...                                   ...
# 597968                                  0
# 597969                                  0
# 597970                                  0
# 597971                                  0
# 597972                                  0
#
#         pedestrian_crossing_physical_facilities  light_conditions  \
# 0                                             0                 5
# 1                                             0                 4
# 2                                             0                 4
# 3                                             0                 1
# 4                                             0                 1
# ...                                         ...               ...
# 597968                                        0                 1
# 597969                                        0                 1
# 597970                                        0                 1
# 597971                                        0                 1
# 597972                                        0                 1
#
#         weather_conditions  road_surface_conditions  \
# 0                        1                        1
# 1                        1                        1
# 2                        1                        1
# 3                        1                        1
# 4                        1                        1
# ...                    ...                      ...
# 597968                   1                        1
# 597969                   1                        1
# 597970                   1                        1
# 597971                   1                        1
# 597972                   1                        1
#
#         special_conditions_at_site  carriageway_hazards  urban_or_rural_area  \
# 0                                0                    0                    1
# 1                                0                    0                    1
# 2                                0                    0                    1
# 3                                0                    0                    1
# 4                                0                    0                    1
# ...                            ...                  ...                  ...
# 597968                           0                    0                    1
# 597969                           0                    0                    1
# 597970                           0                    0                    2
# 597971                           0                    0                    1
# 597972                           0                    2                    1
#
#         did_police_officer_attend_scene_of_accident  trunk_road_flag
# 0                                                 1                2
# 1                                                 1                2
# 2                                                 1                2
# 3                                                 1                2
# 4                                                 1                2
# ...                                             ...              ...
# 597968                                            1               -1
# 597969                                            2               -1
# 597970                                            1               -1
# 597971                                            2               -1
# 597972                                            1               -1
#
# [597803 rows x 31 columns]

# %%
def elbow_method(df, max_clusters):
    distortions = []
    for i in range(1, max_clusters + 1):
        kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
        kmeans.fit(df)
        distortions.append(kmeans.inertia_)
    return distortions


max_clusters = 10
distortions = elbow_method(df, max_clusters)

plt.figure(figsize=(10, 6))
plt.plot(range(1, max_clusters + 1), distortions, marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('Distortion')
plt.xticks(range(1, max_clusters + 1))
plt.grid(True)
plt.show()

# %%
distortions
# Out:
# [1.9359192388551096e+16,
#  8555995777322208.0,
#  5793437839409250.0,
#  3520833713083955.5,
#  2817807599637756.0,
#  2447881104812171.5,
#  2092318050495885.5,
#  1797684144438419.5,
#  1501913137161877.2,
#  1323545972610549.2]

# %%
kmodel=KMeans(n_clusters=2,max_iter=150,random_state=50)
kmodel.fit(df)
# Out:
# KMeans(max_iter=150, n_clusters=2, random_state=50)

# %%
kmodel.labels_
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
df['2ClusterID']=kmodel.labels_

# %%
df['2ClusterID'].value_counts()
# Out:
# 2ClusterID
# 1    399461
# 0    198342
# Name: count, dtype: int64

# %%
kmodel=KMeans(n_clusters=3,max_iter=150,random_state=50)
kmodel.fit(df)
# Out:
# KMeans(max_iter=150, n_clusters=3, random_state=50)

# %%
df['3ClusterID']=kmodel.labels_
df['3ClusterID'].value_counts()
# Out:
# 3ClusterID
# 2    336145
# 1    207276
# 0     54382
# Name: count, dtype: int64

# %%
# Scatter plot for 2 clusters
plt.figure(figsize=(10, 6))
for cluster_id in range(2):
    cluster_data = df[df['2ClusterID'] == cluster_id]
    plt.scatter(cluster_data['latitude'], cluster_data['longitude'], label=f'Cluster {cluster_id}')

plt.xlabel('latitude')
plt.ylabel('longitude')
plt.title('2-Cluster Visualization')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Scatter plot for 3 clusters
plt.figure(figsize=(10, 6))
for cluster_id in range(3):
    cluster_data = df[df['3ClusterID'] == cluster_id]
    plt.scatter(cluster_data['latitude'], cluster_data['longitude'], label=f'Cluster {cluster_id}')

plt.xlabel('latitude')
plt.ylabel('longitude')
plt.title('3-Cluster Visualization')
plt.legend()
plt.grid(True)
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
for cluster_id in range(3):
    cluster_data = df[df['3ClusterID'] == cluster_id]
    ax.scatter(cluster_data['latitude'], cluster_data['longitude'], cluster_data['time'], label=f'Cluster {cluster_id}')
    
ax.set_xlabel('Latitude')
ax.set_ylabel('Longitude')
ax.set_zlabel('Time')

plt.show()

# %%
dbscan_data=df.drop(columns=['2ClusterID','3ClusterID'])

# %%
dbscan = DBSCAN(eps=10,min_samples=1000) #Adjust eps and min_samples as needed
clusters=dbscan.fit_predict(dbscan_data)
dbscan.labels_
# Out:
# array([-1, -1, -1, ..., -1, -1, -1], dtype=int64)

# %%
plt.scatter(dbscan_data['latitude'], dbscan_data['longitude'], c=clusters, cmap='viridis')
plt.xlabel('latitude')
plt.ylabel('longitude')
plt.title('DBSCAN Clustering')
plt.colorbar(label='Cluster ID')
plt.show()
